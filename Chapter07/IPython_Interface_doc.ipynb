# %% [markdown]
# # **User Guide for Interactive GenAISys Chat Interface**
# Interactive interface, copyright 2025, Denis Rothman
#
# This document applies to the GenAISys interface starting Chapter 7
#
# Last updated February 9,2025
# ---Doc generated by DeepSeek/OpenAI copilots.----
#
# ## **Introduction**
# This guide provides step-by-step instructions on how to use the interactive chat interface. This interface allows multiple users to engage in conversations with an AI-powered assistant, with options for reasoning, file handling, text-to-speech (TTS), and selecting different AI models.
#
# ---
#
# ## **Table of Contents**
# 1. **Getting Started**
# 2. **User Interface Components**
# 3. **How to Start a Conversation**
# 4. **Using Reasoning Modes**
# 5. **AI Model Selection**
# 6. **Using Text-to-Speech (TTS)**
# 7. **Managing Conversations**
# 8. **Saving Conversation History**
# 9. **Ending the Conversation**
# 10. **Troubleshooting & FAQs**
#
# ---
#
# ## **1. Getting Started**
# The chat interface initializes with a default user, and you can select different users to engage in conversation. The assistant provides responses based on user input and can process various commands.
#
# ---
#
# ## **2. User Interface Components**
# The interface consists of the following elements:
#
# - **User Selector**: Dropdown menu to switch between different users.
# - **Message Input Box**: A text area where users can type their messages.
# - **Submit Button**: Sends the entered message for processing.
# - **Agent Checkbox**: Enables or disables the AI assistant's responses.
# - **Voice Output (TTS) Checkbox**: Enables text-to-speech conversion for responses.
# - **Files Checkbox**: Enables file-related interactions.
# - **Reasoning Selector**: Dropdown menu to select reasoning types.
# - **Model Selector**: Dropdown menu to choose between different AI models.
# - **Reasoning Output Panel**: Displays additional processing information.
#
# ---
#
# ## **3. How to Start a Conversation**
# 1. **Select a User**
#    - Use the **User Selector** dropdown to choose between `User01`, `User02`, or `User03`.
#
# 2. **Enter Your Message**
#    - Type your message into the **Message Input Box**.
#    - Press `Enter` or click the **Submit Button** to send your message.
#
# 3. **AI Assistant Response**
#    - If the **Agent Checkbox** is checked, the assistant will respond to your message.
#    - The response will be displayed below your input.
#
# ---
#
# ## **4. Using Reasoning Modes**
# The **Reasoning Selector** allows you to choose how the AI processes your request:
#
# - **None**: The assistant provides direct responses.
# - **Analysis**: The assistant processes analytical tasks.
# - **Generation**: The assistant generates creative or structured responses.
# - **Mobility Agent**: Specialized reasoning for mobility-related tasks.
#
# To use a reasoning mode:
# 1. Select the desired mode from the **Reasoning Selector**.
# 2. Enter your message and submit it.
# 3. The assistant will provide an appropriate response based on the selected reasoning mode.
#
# ---
#
# ## **5. AI Model Selection**
# Users can choose between different AI models for responses:
#
# - **OpenAI**: Default AI model with powerful text generation.
# - **DeepSeek**: Alternative AI model with different response patterns.
#
# To change the AI model:
# 1. Use the **Model Selector** dropdown.
# 2. Choose your preferred model.
# 3. Submit your message for the model to respond.
#
# ---
#
# ## **6. Using Text-to-Speech (TTS)**
# - Enabling the **Voice Output (TTS) Checkbox** converts responses into speech.
# - When checked, the assistant’s responses will be spoken aloud.
# - Disabling it will keep responses text-only.
#
# ---
#
# ## **7. Managing Conversations**
# - **Switching Users**: Use the **User Selector** dropdown to change active users.
# - **Tracking Conversations**: Each user has a separate conversation history.
# - **Clearing Conversations**: The conversation resets when the system is restarted.
#
# ---
#
# ## **8. Saving Conversation History**
# - The chat automatically saves conversation history in a file named `conversation_history.json`.
# - History is stored when the conversation ends using the **Exit Command**.
#
# ---
#
# ## **9. Ending the Conversation**
# - To end a conversation, type:
#   ```
#   exit
#   ```
#   or
#   ```
#   quit
#   ```
# - The conversation will end, and history will be saved automatically.
#
# ---
#
# ## **10. Troubleshooting & FAQs**
# ### **Q: The assistant is not responding. What should I do?**
# - Ensure the **Agent Checkbox** is checked.
# - Verify that a valid message is entered before submitting.
#
# ### **Q: How can I clear the chat history?**
# - Manually delete the `conversation_history.json` file or restart the interface.
#
# ### **Q: How do I change the reasoning mode?**
# - Use the **Reasoning Selector** dropdown to switch between modes.
#
# ### **Q: How do I enable voice output?**
# - Check the **Voice Output (TTS) Checkbox** before submitting your message.
#
# ---
#
# ## **Conclusion**
# This interactive chat interface allows users to engage with an AI assistant in various reasoning modes, select different AI models, and enable voice output. It also supports saving conversation history and managing multiple users. Use the provided options to customize your experience! 🚀
